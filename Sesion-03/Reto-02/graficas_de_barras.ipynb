# %% [markdown]
# ## Reto 2: Gráficas de barras
#
# ### 1. Objetivos:
#     - Aprender a hacer gráficas de barras de distintos tipos
#
# ---
#
# ### 2. Desarrollo:

# %% [markdown]
# Para este ejercicio vamos a utilizar el dataset 'melbourne_housing-clean.csv'. La fuente original [está aquí](https://www.kaggle.com/anthonypino/melbourne-housing-market), en caso de que quieras recordar de qué trata.
#
# Realiza 1 de estas 3 gráficas de barras utilizando este dataset. Las instrucciones para cada una son las siguientes:
#
# 1. Gráfica de barras *verticales* usando la columna `rooms`. El eje y será el *conteo de frecuencia* de cada categoría. Las barras tienen que quedar *ordenadas en orden descendente* (es decir, de la más larga a la màs corta). Para lograr ordenarlas, tendrás que revisar [la documentación](https://seaborn.pydata.org/generated/seaborn.barplot.html) de la gráfica de barras de Seaborn.
#
# 2. Gráfica de barras *verticales* de la columna `types`. El eje y será el *porcentaje de frecuencia* de cada categoría.
#
# 3. Gráfica de barras *h*orizontales* de la columna `council_area`. El eje x será el *conteo de frecuencia* de cada categoría.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../Datasets/melbourne_housing-clean.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0          int64
# suburb             object
# address            object
# rooms               int64
# type               object
# price             float64
# method             object
# seller_g           object
# date               object
# distance          float64
# postcode          float64
# bedroom_2         float64
# bathroom          float64
# car               float64
# land_size         float64
# council_area       object
# latitude          float64
# longitude         float64
# region_name        object
# property_count    float64
# dtype: object

# %%
#No sirve
#count = df['rooms'].value_counts()
#counts = count.sort_values(ascending=True)

# %%
rooms_count = df['rooms'].value_counts()
ax = sns.barplot(rooms_count.index, rooms_count, order=rooms_count.index, label="hay juan")
ax.set(title='Número de cuartos', xlabel='cuartos',ylabel='count')
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# [Text(0.5, 1.0, 'Número de cuartos'),
#  Text(0.5, 0, 'cuartos'),
#  Text(0, 0.5, 'count')]

# %%
#Failed
#sns.barplot(x=counts.index,y=counts)
#sns.barplot(x=count.index,y=count, order=[3,2,4,1,5,6,7,8])

# %%
types
# Out:
# h    7762
# u    2859
# t    1025
# Name: type, dtype: int64

# %%
#2 Gráfica de barras verticales de la columna types. 
#El eje y será el porcentaje de frecuencia de cada categoría.
import matplotlib.ticker

types = df['type'].value_counts()

maximo = types.sum()
types = types / maximo * 100
ax = sns.barplot(x=types.index, y=types)
ax.yaxis.set_major_formatter(matplotlib.ticker.PercentFormatter())
ax.set(title="types",xlabel='tipos',ylabel='frecuencia')
#plt.subplots(figsize=(3,6))
# Out:
# [Text(0.5, 1.0, 'types'), Text(0.5, 0, 'tipos'), Text(0, 0.5, 'frecuencia')]

# %%
area = df['council_area'].value_counts()

maximo = area.sum()
area = area / maximo * 100
#ax = sns.barplot(x=area,y=area.index)
sns.barplot(area, area.index, orient='h')
ax.yaxis.set_major_formatter(matplotlib.ticker.PercentFormatter())
ax.set(title="types",xlabel='tipos',ylabel='frecuencia')
plt.rcParams["figure.figsize"] = (5, 6)
#ax.figsize(6,6)
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <details><summary>Solución</summary>
#
# ```python
# rooms_count = df['rooms'].value_counts()
# sns.barplot(rooms_count.index, rooms_count, order=rooms_count.index)
# type_counts = df['type'].value_counts()
# type_counts = type_counts * 100 / type_counts.sum()
# sns.barplot(type_counts.index, type_counts)
# plt.figure(figsize=(5, 10))
# sns.barplot(council_counts, council_counts.index, orient='h')
# ```
#
# </details>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f8149d1c-e6b1-497a-9109-f01641a8231a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
